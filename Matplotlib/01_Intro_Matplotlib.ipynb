# %% [markdown]
# ## Intro to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-whitegrid')

# %%
plt.plot();

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(x, y, color="red");

# %% [markdown]
# # pyplot API_Object-Oriented API

# %% [markdown]
# - pyplot API -> Quickly
# - OO API -> Advanced

# %% [markdown]
# # Pyplot API

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color='blue', linestyle='dashed', label='sin(x)');
plt.plot(x, np.cos(x), color='red', label='cos(x)')

plt.title('Sin(x) and Cos(x)')
plt.xlabel('Bien X')
plt.ylabel('F(X)')

# plt.xlim([0,4])
# plt.ylim([-1, 2])

# plt.axis([xmin, xmax, ymin, ymax])
# plt.axis([-4, 4, -6, 6])
plt.axis('equal')
# plt.axis('tight')

plt.legend();

# %% [markdown]
# # oo API

# %%
#step1: Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
#step2: Setup plot
fig, ax = plt.subplots(figsize=(5,5)) # figure size = Width & Height of the plot
#step3: Plot the data
ax.plot(x, y);
ax.set(title='A simple plot',
       xlabel='x-axis',
       ylabel='y-axis');

# %% [markdown]
# # Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots()

# %% [markdown]
# ## line

# %%
# Create an array
x = np.linspace(0, 10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
# oo API plot a line chart
fix, ax = plt.subplots()
ax.plot(x, x**3);

# %% [markdown]
# ## Scatter

# %%
# Biểu đồ phân tán
    # Pyplot API
plt.scatter(x, np.exp(x));

# %%
# 00 API
#prepare new data

rng = np.random.RandomState(0) 

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
sizes = 1000*rng.rand(100)
fig,ax = plt.subplots()
img1 = ax.scatter(x, y, s=sizes, c=colors, cmap='viridis', alpha=0.3);

fig.colorbar(img1);

# %% [markdown]
# ## Bar
# * vertical: cột đứng
# * Horizontal: cột ngang

# %%
# prepare data from a python dictionary
soft_drink_prices = {'Coke': 10,
                     'Pessi': 12,
                     'Sprite': 8}
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax.set(title = 'BACH HOA ', ylabel='Price ($)');

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

# %% [markdown]
#   ## Histogram

# %%
#prepare data
np.random.seed(0)
student_height = np.random.normal(170, 10, 250)

# %%
student_height[:10]
len(student_height)
# Out:
# 250

# %%
# pyplot API
plt.hist(student_height, bins=30);

# %%
fig, ax = plt.subplots()
ax.hist(student_height);

# %% [markdown]
# # Subplots

# %%
# Option 1:
fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))

# plot data to each axis
ax1.plot(x, x/2);
ax1.plot(x, x*2);

ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax4.hist(student_height, bins=30);

# %%
# Option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
ax[0,0].plot(x, x/2);
ax[0,1].hist(student_height, bins=30);
ax[1,0].scatter(np.random.random(10), np.random.random(10));
ax[1,1].bar(soft_drink_prices.keys(), soft_drink_prices.values());

# %% [markdown]
# # PROJECT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('')
